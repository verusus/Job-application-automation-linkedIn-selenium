# %%
from selenium import webdriver
from selenium.webdriver import Keys
from selenium.webdriver.common.by import By
from linkedin_scraper import actions
import re
from pprint import pprint
import pandas as pd

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option("detach", True)
driver = webdriver.Chrome(options=chrome_options)

#email = "salhiabdelhamid01@gmail.com"
#password = "TEST@TEST11"
email = "essalhi12345@gmail.com"
password = "HAMID@ESSALHI11"

actions.login(driver, email, password, timeout=30)  # if email and password isnt given, it'll prompt in terminal

# %%
for i in range(0, 600):
    driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.PAGE_DOWN)

# %%
posts_content_list = driver.find_elements(By.XPATH, "//div[@data-id]")
filtered_posts = {}
print(f"The number of posts treated is: {len(posts_content_list)}")
# Out:
# The number of posts treated is: 485

# %%
def calculate_weight(keywords_list, dict_key):
    for key in keywords_list:
        if key in normalized_post:
            post_dict[dict_key] += 1

# %%
prerequested_keywords = ["java", "jee", "j2e", "spring", "angular", "python", "data science", "data analyst", "data scientist", "data engineer", "jupyter"]
exclude_keywords = ["يهود", "صهيوني", "deces", "cancer", "depression", "malaise", "malade", "maladie", "sick", "israel", "palestine", "feel", "pain", "trick", "astuce", "course", "cours", "i'm glad", "i am glad", "i would love", "book", "I would like to thank", "remercier", "big thank", "quotidien", "B2B", "marketing", "paid", "trial", "stage", "pfe", "soutenance", "erreur", "famille", "amis", 
                    "family", "friends", "soutien", "thesis", "gratitude", "grateful",
                    "supervisor", "support", "at least 4", "at least 5", "at least 6", "at least 7", "at least 8",
                    "8 ans", "7 ans", "6 ans", "5 ans", "4 ans", "8ans", "7ans", "6ans", "5ans", "4ans",
                     "8 year", "7 year", "6 year", "5 year", "4 year", "8year", "7year", "6year", "5year", "4year", "préten",
                   "conseil", "les recruteurs", "immense", "suis ravi", "finance", "business", "pleased to", "profonde"]
is_hiring = ["@", "resume", "cv", "recrutement", "join", "rejoin", "recrute", "ressource", "recruit", "hiring", "hire", "job", "work", 
             "hr", "talent", "aquisition", "human", "fresher", "jobopening", "opening", "seek",
             "postule", "challenge", "role", "reach", "contrat", "cdi", "cdd", "freelance",
             "application", "condidature", "resource", "humain", "recherche", "look", "offre", "offer", "opening",
             "employment", "opportunit", "vacanc", "career", "position", "emploi", "poste", "carriere", "embauche"]
is_first_priority = ["junior", "jr", "jnr", "fraichement", "young", "graduated", "graduates", "entry"]

python_keywords = ["beautifulsoup", "bs4", "playwright", "openpyxl", "scraping", "scrap", "pandas",
                   "pycharm", "tkinter", "django", "flask", "data",
                   "jupyter", "analysis"]
java_keywords = ["spring", "boot", "angular", "hibernate", "hql"]
common_keywords = ["css", "html", "ingenieur", "engineer", "excel", "backend", "back end", "back-end", "frontend", "front end", "front-end", "selenium", "web", "api", "security", "keycloack", "developer", "full",
                   "stack", "developpeur", "git", "program", "automation", "automatisation", "data", "données",
                   "software", "scrum", "agile", "oracle", "twilio", "tequila", "sql", "docker", "ci", "cd", "qa"]

# %%
def no_excluded(post):
    """if no keyword from the excluded list is present in the post, it returns True"""
    for exclude_key in exclude_keywords:
        if exclude_key in post:
            return False
    return True

def is_today(post):
    """checks the post if it is posted today and ignores sponsored posts"""
    # Define the pattern using regular expression
    pattern = r'\b\d{1,2}[mh]\b'  # Matches one to three digits followed by m or h

    # Use re.search() to find the pattern in the text
    match = re.search(pattern, post.text.split(" •")[0])

    # If there is a match, return True, else return False
    if match:
        return True
    else:
        return False

# %%
post_urls = []

for post in posts_content_list:
    normalized_post = post.text.lower().replace("é", "e").replace("è", "e").replace("ù", "u").replace("û", "u") \
        .replace("î", "i")
    for prerequested_keyword in prerequested_keywords:
        post_dict = {"hiring_weight": 0, "priority_weight": 0, "python_weight": 0,
                     "java_weight": 0, "common_weight": 0, "post_url": ""}
        if prerequested_keyword in normalized_post and no_excluded(normalized_post) and is_today(post):
            # print(f"https://www.linkedin.com/feed/update/{post.get_attribute('data-id')}/")
            # todo: check weither the url is already exists or not
            post_url = f"https://www.linkedin.com/feed/update/{post.get_attribute('data-id')}/"
            if post_url not in post_urls:
                calculate_weight(is_hiring, "hiring_weight")
                calculate_weight(is_first_priority, "priority_weight")
                calculate_weight(python_keywords, "python_weight")
                calculate_weight(java_keywords, "java_weight")
                calculate_weight(common_keywords, "common_weight")
                post_dict["post_url"] = post_url
                post_urls.append(post_url)
                try:
                    filtered_posts[prerequested_keyword]["posts"].append(post_dict)
                except KeyError:
                    filtered_posts[prerequested_keyword] = {"posts": [post_dict]}
# todo: check if not promoted then filter only those with m for minutes and h for hours

# %%
# make counts 
for key in filtered_posts.keys():
    
    filtered_posts[key]["count"] = len(filtered_posts[key]["posts"])
pprint(filtered_posts)
# todo: delete similar urls
# Out:
# {'analyst': {'count': 2,
#              'posts': [{'common_weight': 6,
#                         'hiring_weight': 2,
#                         'java_weight': 0,
#                         'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122492058073710592/',
#                         'priority_weight': 0,
#                         'python_weight': 0},
#                        {'common_weight': 1,
#                         'hiring_weight': 4,
#                         'java_weight': 0,
#                         'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122314181122355200/',
#                         'priority_weight': 0,
#                         'python_weight': 0}]},
#  'data': {'count': 10,
#           'posts': [{'common_weight': 6,
#                      'hiring_weight': 2,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122308793513693184/',
#                      'priority_weight': 0,
#                      'python_weight': 1},
#                     {'common_weight': 3,
#                      'hiring_weight': 2,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122491594842202112/',
#                      'priority_weight': 0,
#                      'python_weight': 1},
#                     {'common_weight': 3,
#                      'hiring_weight': 1,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122499318254555137/',
#                      'priority_weight': 0,
#                      'python_weight': 1},
#                     {'common_weight': 4,
#                      'hiring_weight': 3,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122506635817734144/',
#                      'priority_weight': 0,
#                      'python_weight': 1},
#                     {'common_weight': 6,
#                      'hiring_weight': 6,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122503003881795585/',
#                      'priority_weight': 0,
#                      'python_weight': 2},
#                     {'common_weight': 3,
#                      'hiring_weight': 1,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122547803075039232/',
#                      'priority_weight': 0,
#                      'python_weight': 1},
#                     {'common_weight': 4,
#                      'hiring_weight': 1,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122490082950795264/',
#                      'priority_weight': 0,
#                      'python_weight': 1},
#                     {'common_weight': 3,
#                      'hiring_weight': 4,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122531187905961984/',
#                      'priority_weight': 0,
#                      'python_weight': 2},
#                     {'common_weight': 2,
#                      'hiring_weight': 0,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122502969052258304/',
#                      'priority_weight': 0,
#                      'python_weight': 1},
#                     {'common_weight': 2,
#                      'hiring_weight': 1,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122491937974009856/',
#                      'priority_weight': 0,
#                      'python_weight': 1}]},
#  'java': {'count': 3,
#           'posts': [{'common_weight': 4,
#                      'hiring_weight': 2,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122517066305183744/',
#                      'priority_weight': 0,
#                      'python_weight': 0},
#                     {'common_weight': 2,
#                      'hiring_weight': 3,
#                      'java_weight': 0,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122540239193010177/',
#                      'priority_weight': 0,
#                      'python_weight': 0},
#                     {'common_weight': 5,
#                      'hiring_weight': 4,
#                      'java_weight': 1,
#                      'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122245686305189891/',
#                      'priority_weight': 0,
#                      'python_weight': 0}]},
#  'python': {'count': 5,
#             'posts': [{'common_weight': 5,
#                        'hiring_weight': 6,
#                        'java_weight': 0,
#                        'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122472768029212674/',
#                        'priority_weight': 0,
#                        'python_weight': 0},
#                       {'common_weight': 2,
#                        'hiring_weight': 2,
#                        'java_weight': 0,
#                        'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122476823648579585/',
#                        'priority_weight': 0,
#                        'python_weight': 0},
#                       {'common_weight': 2,
#                        'hiring_weight': 1,
#                        'java_weight': 0,
#                        'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122510376453165056/',
#                        'priority_weight': 0,
#                        'python_weight': 0},
#                       {'common_weight': 5,
#                        'hiring_weight': 1,
#                        'java_weight': 0,
#                        'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122283549193314304/',
#                        'priority_weight': 0,
#                        'python_weight': 0},
#                       {'common_weight': 1,
#                        'hiring_weight': 0,
#                        'java_weight': 0,
#                        'post_url': 'https://www.linkedin.com/feed/update/urn:li:activity:7122229954792099840/',
#                        'priority_weight': 0,
#                        'python_weight': 0}]}}

# %%
flattened_data = []
for category, info in filtered_posts.items():
    count = info['count']
    for post in info['posts']:
        hiring_weight = post['hiring_weight']
        priority_weight = post['priority_weight']
        python_weight = post['python_weight']
        java_weight = post['java_weight']
        common_weight = post['common_weight']
        post_url = post['post_url']
        flattened_data.append([category, count, hiring_weight, priority_weight, python_weight, java_weight, common_weight, post_url])

# Create a pandas DataFrame
columns = ['category', 'count', 'hiring_weight', 'priority_weight', 'python_weight', 'java_weight', 'common_weight', 'post_url']
df = pd.DataFrame(flattened_data, columns=columns)

# Print the resulting DataFrame
print(df)
# Out:
#    category  count  hiring_weight  priority_weight  python_weight  \
# 0    python      5              6                0              0
# 1    python      5              2                0              0
# 2    python      5              1                0              0
# 3    python      5              1                0              0
# 4    python      5              0                0              0
# 5      data     10              2                0              1
# 6      data     10              2                0              1
# 7      data     10              1                0              1
# 8      data     10              3                0              1
# 9      data     10              6                0              2
# 10     data     10              1                0              1
# 11     data     10              1                0              1
# 12     data     10              4                0              2
# 13     data     10              0                0              1
# 14     data     10              1                0              1
# 15     java      3              2                0              0
# 16     java      3              3                0              0
# 17     java      3              4                0              0
# 18  analyst      2              2                0              0
# 19  analyst      2              4                0              0
#
#     java_weight  common_weight  \
# 0             0              5
# 1             0              2
# 2             0              2
# 3             0              5
# 4             0              1
# 5             0              6
# 6             0              3
# 7             0              3
# 8             0              4
# 9             0              6
# 10            0              3
# 11            0              4
# 12            0              3
# 13            0              2
# 14            0              2
# 15            0              4
# 16            0              2
# 17            1              5
# 18            0              6
# 19            0              1
#
#                                              post_url
# 0   https://www.linkedin.com/feed/update/urn:li:ac...
# 1   https://www.linkedin.com/feed/update/urn:li:ac...
# 2   https://www.linkedin.com/feed/update/urn:li:ac...
# 3   https://www.linkedin.com/feed/update/urn:li:ac...
# 4   https://www.linkedin.com/feed/update/urn:li:ac...
# 5   https://www.linkedin.com/feed/update/urn:li:ac...
# 6   https://www.linkedin.com/feed/update/urn:li:ac...
# 7   https://www.linkedin.com/feed/update/urn:li:ac...
# 8   https://www.linkedin.com/feed/update/urn:li:ac...
# 9   https://www.linkedin.com/feed/update/urn:li:ac...
# 10  https://www.linkedin.com/feed/update/urn:li:ac...
# 11  https://www.linkedin.com/feed/update/urn:li:ac...
# 12  https://www.linkedin.com/feed/update/urn:li:ac...
# 13  https://www.linkedin.com/feed/update/urn:li:ac...
# 14  https://www.linkedin.com/feed/update/urn:li:ac...
# 15  https://www.linkedin.com/feed/update/urn:li:ac...
# 16  https://www.linkedin.com/feed/update/urn:li:ac...
# 17  https://www.linkedin.com/feed/update/urn:li:ac...
# 18  https://www.linkedin.com/feed/update/urn:li:ac...
# 19  https://www.linkedin.com/feed/update/urn:li:ac...

# %%
sorted_df = df.sort_values(by=['category', 'hiring_weight', 'priority_weight', 'python_weight', 'java_weight', 'common_weight'], ascending=[True, False, False, False, False, False])
print(sorted_df)
# Out:
#    category  count  hiring_weight  priority_weight  python_weight  \
# 19  analyst      2              4                0              0
# 18  analyst      2              2                0              0
# 9      data     10              6                0              2
# 12     data     10              4                0              2
# 8      data     10              3                0              1
# 5      data     10              2                0              1
# 6      data     10              2                0              1
# 11     data     10              1                0              1
# 7      data     10              1                0              1
# 10     data     10              1                0              1
# 14     data     10              1                0              1
# 13     data     10              0                0              1
# 17     java      3              4                0              0
# 16     java      3              3                0              0
# 15     java      3              2                0              0
# 0    python      5              6                0              0
# 1    python      5              2                0              0
# 3    python      5              1                0              0
# 2    python      5              1                0              0
# 4    python      5              0                0              0
#
#     java_weight  common_weight  \
# 19            0              1
# 18            0              6
# 9             0              6
# 12            0              3
# 8             0              4
# 5             0              6
# 6             0              3
# 11            0              4
# 7             0              3
# 10            0              3
# 14            0              2
# 13            0              2
# 17            1              5
# 16            0              2
# 15            0              4
# 0             0              5
# 1             0              2
# 3             0              5
# 2             0              2
# 4             0              1
#
#                                              post_url
# 19  https://www.linkedin.com/feed/update/urn:li:ac...
# 18  https://www.linkedin.com/feed/update/urn:li:ac...
# 9   https://www.linkedin.com/feed/update/urn:li:ac...
# 12  https://www.linkedin.com/feed/update/urn:li:ac...
# 8   https://www.linkedin.com/feed/update/urn:li:ac...
# 5   https://www.linkedin.com/feed/update/urn:li:ac...
# 6   https://www.linkedin.com/feed/update/urn:li:ac...
# 11  https://www.linkedin.com/feed/update/urn:li:ac...
# 7   https://www.linkedin.com/feed/update/urn:li:ac...
# 10  https://www.linkedin.com/feed/update/urn:li:ac...
# 14  https://www.linkedin.com/feed/update/urn:li:ac...
# 13  https://www.linkedin.com/feed/update/urn:li:ac...
# 17  https://www.linkedin.com/feed/update/urn:li:ac...
# 16  https://www.linkedin.com/feed/update/urn:li:ac...
# 15  https://www.linkedin.com/feed/update/urn:li:ac...
# 0   https://www.linkedin.com/feed/update/urn:li:ac...
# 1   https://www.linkedin.com/feed/update/urn:li:ac...
# 3   https://www.linkedin.com/feed/update/urn:li:ac...
# 2   https://www.linkedin.com/feed/update/urn:li:ac...
# 4   https://www.linkedin.com/feed/update/urn:li:ac...

# %%
sorted_df.to_excel('C:\\Users\\Administrator\\Desktop\\sorted_data.xlsx', index=False)

# %%
# todo: categorize weights and multiply depending on importance
post_urls = []
filtered_posts = {}
normalized_post = "#hiring nous recrutons un developpeur python junior jr jnr"
for prerequested_keyword in prerequested_keywords:
    post_dict = {"hiring_weight": 0, "priority_weight": 0, "python_weight": 0,
                 "java_weight": 0, "common_weight": 0, "post_url": ""}
    if prerequested_keyword in normalized_post and no_excluded(normalized_post):
        # print(f"https://www.linkedin.com/feed/update/{post.get_attribute('data-id')}/")
        # todo: check weither the url is already exists or not
        post_url = f"https://www.linkedin.com/feed/update/"
        if post_url not in post_urls:
            calculate_weight(is_hiring, "hiring_weight")
            calculate_weight(is_first_priority, "priority_weight")
            calculate_weight(python_keywords, "python_weight")
            calculate_weight(java_keywords, "java_weight")
            calculate_weight(common_keywords, "common_weight")
            post_dict["post_url"] = post_url
            post_urls.append(post_url)
            try:
                filtered_posts[prerequested_keyword]["posts"].append(post_dict)
            except KeyError:
                filtered_posts[prerequested_keyword] = {"posts": [post_dict]}
pprint(filtered_posts)
# Out:
# {'python': {'posts': [{'common_weight': 1,
#                        'hiring_weight': 1,
#                        'java_weight': 0,
#                        'post_url': 'https://www.linkedin.com/feed/update/',
#                        'priority_weight': 3,
#                        'python_weight': 0}]}}
